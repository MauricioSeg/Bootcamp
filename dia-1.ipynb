# %%
print ("hola mundo ")
# Out:
# hola mundo

# %%
nombre = "Mauricio"
edad = 25
Ciudad = "Asuncion"
print (nombre, edad, Ciudad)
# Out:
# Mauricio 25 Asuncion

# %%
cantidad_de_manzanas = 10
cantidad_de_naranjas = 5
cantidad_frutas = cantidad_de_manzanas + cantidad_de_naranjas

print ("En total tenemos:", cantidad_frutas,"Frutas")

frutas_vendidas = 3 
frutas_restantes = cantidad_frutas - frutas_vendidas
print(" Nos sobran:", frutas_restantes,"Frutas")
# Out:
# En total tenemos: 15 Frutas
#  Nos sobran: 12 Frutas

# %%
nombre = "Matias"
apellido = "Falcon"

print(F"Hola mi nombre es {nombre} {apellido}. Que tenga un lindo dia!")
# Out:
# Hola mi nombre es Matias Falcon. Que tenga un lindo dia!

# %%
caramelos=int(input("Ingrese cantidad de caramelos totales"))
ninos=int(input("Ingrese cantidad de niños"))
caramelos_por_nino= caramelos//ninos
sobrante= caramelos%ninos
print("son ",caramelos_por_nino," caramelos por niño y sobran ",sobrante,"caramelos")
# Out:
# son  5  caramelos por niño y sobran  0 caramelos

# %%
def direccion_de_envio():
    calle=input("Ingrese su calle")
    numero_de_casa=int(input("Ingrese su numero de casa"))
    print(F"Enviar el paquete a {calle} {numero_de_casa}")
    
direccion_de_envio()
direccion_de_envio()
direccion_de_envio()
# Out:
# Enviar el paquete a Facundo Machain 1
# Enviar el paquete a Choferes 2
# Enviar el paquete a España 3

# %%
numero_de_huespedes = int(input("Ingrese numero de Huspedes"))
cantidad_de_noches = int(input(" Numero de Noches"))

def solicitud_de_reservas (huespedes,noches):
    print(F"Hemos recibido su reserva para una habitacion para {huespedes} huespedes, por {noches} noches")
    print (" Su reserva fue realiza con exito, Muchas gracias")
solicitud_de_reservas(numero_de_huespedes,cantidad_de_noches)
# Out:
# Hemos recibido su reserva para una habitacion para 2 huespedes, por 3 noches
#  Su reserva fue realiza con exito, Muchas gracias

# %%
impuesto = 1.1
precio_del_producto = int(input("Ingresa el precio del producto: "))
def calcular_total(precio):
    total = precio * impuesto
    print (F"El total a pagar es {total}")

calcular_total(precio_del_producto)
# Out:
# El total a pagar es 5500.0
